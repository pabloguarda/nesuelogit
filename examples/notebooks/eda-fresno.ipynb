# %% [markdown]
# ## Setup

# %%
import os
import sys
from pathlib import Path
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import time

import numpy as np
import pandas as pd
import isuelogit as isl
import glob

# %%
# Path management
main_dir = str(Path(os.path.abspath('')).parents[1])
os.chdir(main_dir)
print('main dir:', main_dir)

sys.path.append(os.path.join(main_dir, 'src'))

isl.config.dirs['read_network_data'] = "input/network-data/fresno/"
# Out:
# main dir: /Users/pablo/github/nesuelogit

# %%
# Internal modules
from pesuelogit.etl import data_curation, add_period_id

# %% [markdown]
# ## Read spatiotemporal data

# %%
folderpath = isl.config.dirs['read_network_data'] + 'links/spatiotemporal-data/'
df = pd.concat([pd.read_csv(file) for file in glob.glob(folderpath + "*link-data*")], axis=0)

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df[df['date'].dt.dayofweek.between(0, 3)]
# df = df[df['date'].dt.year == 2019]

df['period'] = df['date'].astype(str) + '-' + df['hour'].astype(str)
df['period'] = df.period.map(hash)

# %%
# Add period id for timevarying estimation

period_feature = 'hour'

df['period'] = df['date'].astype(str) + '-' + df[period_feature].astype(str)
# df['period'] = df.period.map(hash)

df = add_period_id(df, period_feature='hour')

period_keys = df[[period_feature,'period_id']].drop_duplicates().reset_index().drop('index',axis =1).sort_values('hour')
print(period_keys)
# Out:
#     hour  period_id
# 11     6          0
# 12     7          1
# 13     8          2
# 14     9          3
# 0     10          4
# 1     11          5
# 2     12          6
# 3     13          7
# 4     14          8
# 5     15          9
# 6     16         10
# 7     17         11
# 8     18         12
# 9     19         13
# 10    20         14

# %% [markdown]
# ## Data curation

# %%
df['tt_ff'] = np.where(df['link_type'] != 'LWRLK', 0,df['length']/df['speed_ref_avg'])
df.loc[(df.link_type == "LWRLK") & (df.speed_ref_avg == 0),'tt_ff'] = float('nan')

df['tt_avg'] = np.where(df['link_type'] != 'LWRLK', 0,df['length']/df['speed_hist_avg'])
df.loc[(df.link_type == "LWRLK") & (df.speed_hist_avg == 0),'tt_avg'] = float('nan')

df = data_curation(df)

# %%
# Observed counts as used as a measure of how congested are the links, thus, they are normalized by link capacity
df = pd.merge(df, df.groupby('link_key')[['counts']].max().rename(columns ={'counts':'counts_max'}), on = 'link_key')
df['counts']= df['counts']/df['counts_max']*df['k']

# %%
df[['speed_ref_avg','speed_hist_avg', 'tt_ff', 'tt_avg']].describe()
# Out:
#        speed_ref_avg  speed_hist_avg         tt_ff         tt_avg
# count   1.013460e+06    1.009583e+06  1.013460e+06  887813.000000
# mean    1.924470e+01    1.767589e+01  3.397371e-03       0.003658
# std     1.982261e+01    1.909664e+01  4.350074e-03       0.004367
# min     0.000000e+00    0.000000e+00  0.000000e+00       0.000000
# 25%     0.000000e+00    0.000000e+00  0.000000e+00       0.000000
# 50%     2.112700e+01    1.755400e+01  2.495627e-03       0.002784
# 75%     2.796200e+01    2.547600e+01  4.653995e-03       0.005216
# max     6.772900e+01    7.891400e+01  7.034335e-02       0.063791

# %% [markdown]
# ## Data processing

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['year'] = df.date.dt.year

# %%
df.query('year == 2019')[['counts', 'tt_ff', 'tt_avg', 'tf_inrix', 'speed_avg']].describe()
# Out:
#              counts          tt_ff         tt_avg       tf_inrix  \
# count  31624.000000  542925.000000  468303.000000  542925.000000
# mean    1488.711817       0.003415       0.003699       0.200169
# std      462.285984       0.004370       0.004448       0.228208
# min        0.779896       0.000000       0.000000       0.000000
# 25%     1188.724832       0.000000       0.000000       0.000000
# 50%     1494.280386       0.002508       0.002814       0.152000
# 75%     1823.017903       0.004702       0.005304       0.280000
# max     2400.000000       0.070343       0.063791       2.302000
#
#            speed_avg
# count  542925.000000
# mean       17.946237
# std        20.262676
# min         0.000000
# 25%         0.000000
# 50%        16.000000
# 75%        27.340000
# max        75.652000

# %%
df.query('year == 2020')[['counts', 'tt_ff', 'tt_avg', 'tf_inrix', 'speed_avg']].describe()
# Out:
#              counts          tt_ff         tt_avg       tf_inrix  \
# count  27472.000000  470535.000000  419510.000000  470535.000000
# mean    1351.644684       0.003377       0.003613       0.198494
# std      450.202278       0.004326       0.004275       0.226003
# min        5.725646       0.000000       0.000000       0.000000
# 25%     1038.280415       0.000000       0.000000       0.000000
# 50%     1347.643221       0.002491       0.002756       0.150000
# 75%     1681.922253       0.004578       0.005112       0.273000
# max     2400.000000       0.070343       0.054574       2.113000
#
#            speed_avg
# count  470535.000000
# mean       19.650807
# std        20.229134
# min         0.000000
# 25%         0.000000
# 50%        20.505000
# 75%        28.117000
# max        73.943000

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Link attributes

# %%
features_Z = ['tt_sd', 'median_inc', 'incidents', 'bus_stops', 'intersections']

# %%
features_plot = ['speed_sd', 'median_inc', 'incidents', 'bus_stops', 'intersections']

sns.lineplot(x= 'date', y = 'value', hue = 'variable', data =pd.melt(df.groupby('date')[features_plot].mean().reset_index(),id_vars= ['date']))
plt.tight_layout()
plt.legend(title="")
plt.ylabel("value of exogenous feature")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Targets

# %%
# Single period models
df.loc[(df.hour == 16) & (df.year == 2019),['counts', 'tt_avg']].describe()
# Out:
#             counts        tt_avg
# count  2105.000000  31314.000000
# mean   1849.726640      0.003848
# std     398.003082      0.004593
# min       2.339688      0.000000
# 25%    1623.624161      0.000000
# 50%    1834.551828      0.002906
# 75%    2218.136646      0.005654
# max    2400.000000      0.057115

# %%
df.loc[(df.hour.isin([6,7,8,15,16,17])) & (df.year == 2019),['counts', 'tt_avg']].describe()
# Out:
#              counts         tt_avg
# count  12647.000000  186612.000000
# mean    1693.151833       0.003580
# std      410.468048       0.004315
# min        1.559792       0.000000
# 25%     1413.371674       0.000000
# 50%     1700.761990       0.002716
# 75%     2022.135952       0.005113
# max     2400.000000       0.057115

# %% [markdown]
# ## Analyze single file of inrix data

# %%
inrix_df = pd.read_csv(f"{os.getcwd()}/input/private/inrix/2020-10-01.csv")
inrix_df['ts'] = pd.to_datetime(inrix_df['UTC Date Time'])
inrix_df['hour'] = inrix_df.ts.dt.hour
inrix_df['speed'] = inrix_df['Speed(km/hour)']*0.62137119223

# %%
# Select data from same time range
inrix_df = inrix_df[inrix_df.hour.isin(range(4,23))]

# %%
inrix_df.head()
# Out:
#     Date Time  Segment ID        UTC Date Time  Speed(km/hour)  \
# 4  2020-10-01  1626763236  2020-10-01 04:00:00            52.0
# 5  2020-10-01  1626763236  2020-10-01 04:15:00            51.0
# 6  2020-10-01  1626763236  2020-10-01 04:30:00            47.0
# 7  2020-10-01  1626763236  2020-10-01 04:45:00            45.0
# 8  2020-10-01  1626763236  2020-10-01 05:00:00            48.0
#
#    Hist Av Speed(km/hour)  Ref Speed(km/hour)  Travel Time(Minutes)  CValue  \
# 4                    48.0                42.0                  0.13    90.0
# 5                    47.0                42.0                  0.15    90.0
# 6                    47.0                42.0                  0.15     NaN
# 7                    45.0                42.0                  0.17     NaN
# 8                    48.0                42.0                  0.15     NaN
#
#    Pct Score30  Pct Score20  Pct Score10 Road Closure Corridor/Region Name  \
# 4        100.0          0.0          0.0            F            Fresno_CA
# 5         53.0         47.0          0.0            F            Fresno_CA
# 6          0.0        100.0          0.0            F            Fresno_CA
# 7          0.0        100.0          0.0            F            Fresno_CA
# 8          0.0        100.0          0.0            F            Fresno_CA
#
#                    ts  hour      speed
# 4 2020-10-01 04:00:00     4  32.311302
# 5 2020-10-01 04:15:00     4  31.689931
# 6 2020-10-01 04:30:00     4  29.204446
# 7 2020-10-01 04:45:00     4  27.961704
# 8 2020-10-01 05:00:00     5  29.825817

# %%
inrix_df.describe()
# Out:
#          Segment ID  Speed(km/hour)  Hist Av Speed(km/hour)  \
# count  1.020604e+06    1.020300e+06           940434.000000
# mean   7.942554e+08    5.513983e+01               54.284333
# std    6.271538e+08    2.324176e+01               23.336311
# min    1.684284e+08    6.000000e+00                6.000000
# 25%    3.999621e+08    3.900000e+01               37.000000
# 50%    4.416791e+08    4.900000e+01               48.000000
# 75%    1.626652e+09    7.100000e+01               71.000000
# max    1.626775e+09    1.220000e+02              122.000000
#
#        Ref Speed(km/hour)  Travel Time(Minutes)         CValue   Pct Score30  \
# count        1.020604e+06          1.020300e+06  705930.000000  1.020300e+06
# mean         5.593239e+01          4.545113e-01      95.063257  6.403537e+01
# std          2.250260e+01          4.023858e-01       5.040026  4.606894e+01
# min          1.000000e+01          0.000000e+00      50.000000  0.000000e+00
# 25%          4.000000e+01          1.300000e-01      90.000000  0.000000e+00
# 50%          5.000000e+01          3.500000e-01      96.670000  1.000000e+02
# 75%          7.100000e+01          6.700000e-01     100.000000  1.000000e+02
# max          1.140000e+02          8.170000e+00     100.000000  1.000000e+02
#
#         Pct Score20   Pct Score10          hour         speed
# count  1.020300e+06  1.020300e+06  1.020604e+06  1.020300e+06
# mean   2.810540e+01  7.859205e+00  1.300000e+01  3.426230e+01
# std    4.291665e+01  2.655070e+01  5.477228e+00  1.444176e+01
# min    0.000000e+00  0.000000e+00  4.000000e+00  3.728227e+00
# 25%    0.000000e+00  0.000000e+00  8.000000e+00  2.423348e+01
# 50%    0.000000e+00  0.000000e+00  1.300000e+01  3.044719e+01
# 75%    8.000000e+01  0.000000e+00  1.800000e+01  4.411735e+01
# max    1.000000e+02  1.000000e+02  2.200000e+01  7.580729e+01

# %%
fig, axs = plt.subplots(2,2, figsize = (9,8), tight_layout = True)

sns.lineplot(data = inrix_df.groupby('hour')[['Hist Av Speed(km/hour)']].mean(),
             ax = axs[0,0])

axs[0,0].set_title('avg of historical speed')

sns.lineplot(data = inrix_df.groupby('hour')[['Hist Av Speed(km/hour)']].std(),
             ax = axs[0,1])
axs[0,1].set_title('std of historical speed');

sns.lineplot(data = inrix_df.groupby('hour')[['Speed(km/hour)']].mean(),
             ax = axs[1,0])

axs[1,0].set_title('avg of speed')

sns.lineplot(data = inrix_df.groupby('hour')[['speed']].std(),
             ax = axs[1,1])
axs[1,1].set_title('std of speed');

# %%
# Filter only data from inrix segments that were matched with the network links

fig, axs = plt.subplots(1,2, figsize = (10,4))

sns.lineplot(data = inrix_df[inrix_df['Segment ID'].isin(list(df.inrix_id.dropna().unique()))].groupby('hour')[['speed']].mean(),
             ax = axs[0])
axs[0].set_title('avg of speed')

sns.lineplot(data = inrix_df[inrix_df['Segment ID'].isin(list(df.inrix_id.dropna().unique()))].groupby('hour')[['speed']].std(),
             ax = axs[1])
axs[1].set_title('std of speed');

# %% [markdown]
# ## Stats by date

# %%
# To check that there is a balanced amount of observations per date
obs_date = df.groupby('date')['hour'].count()

# %%
# Stats by date
df.groupby('date')[['speed_sd','speed_avg', 'counts']].mean().assign(total_obs = obs_date)
# Out:
#             speed_sd  speed_avg       counts  total_obs
# date
# 2019-10-01  1.731787  17.175187  1497.588808      36195
# 2019-10-02  1.760109  17.169768  1476.571607      36195
# 2019-10-03  1.754288  17.092304  1509.584533      36195
# 2019-10-08  1.847060  18.165569  1478.300459      36195
# 2019-10-09  1.917923  18.137042  1481.272743      36195
# 2019-10-10  1.830232  18.107925  1514.981758      36195
# 2019-10-15  1.831527  18.114384  1480.838248      36195
# 2019-10-16  1.823680  18.162625  1486.702565      36195
# 2019-10-17  1.832219  18.080860  1501.029287      36195
# 2019-10-22  1.837839  18.175561  1470.843410      36195
# 2019-10-23  1.864443  18.222690  1478.096704      36195
# 2019-10-24  1.848827  18.184814  1474.877009      36195
# 2019-10-29  1.868430  18.167171  1465.606342      36195
# 2019-10-30  1.816364  18.109232  1490.846582      36195
# 2019-10-31  1.882446  18.128430  1524.102867      36195
# 2020-10-01  1.290377  19.579215  1359.944262      36195
# 2020-10-06  1.365919  19.709670  1331.870352      36195
# 2020-10-07  1.327017  19.927088  1334.612549      36195
# 2020-10-08  1.344382  19.969943  1349.797144      36195
# 2020-10-13  1.311842  19.626350  1355.705338      36195
# 2020-10-14  1.300075  19.558364  1358.068966      36195
# 2020-10-15  1.331493  19.621633  1378.649462      36195
# 2020-10-20  1.353743  19.597736  1345.194608      36195
# 2020-10-21  1.325694  19.501768  1337.546170      36195
# 2020-10-22  1.334320  19.591921  1370.720073      36195
# 2020-10-27  1.309348  19.573460  1336.894292      36195
# 2020-10-28  1.324270  19.646064  1342.285896      36195
# 2020-10-29  1.336212  19.557279  1370.069862      36195

# %% [markdown]
# ### Cross sectional

# %%
# eda_df = df[df.year == 2019].copy()
eda_df = df.copy()
eda_df['day'] = eda_df.date.dt.day
eda_df['hour_id'] = eda_df['hour'].astype(str).apply(lambda x: time.strftime("%l%p", time.strptime(x,"%H")))
eda_df['date'] = eda_df['date'].astype(str)

# Transform to monthly income
eda_df['median_inc'] = eda_df['median_inc']/12

# %%
eda_df['hour_id'] = pd.Categorical(eda_df['hour_id'], categories = eda_df[['hour_id', 'hour']].drop_duplicates().sort_values('hour')['hour_id'], ordered = True)

# %%
daily_counts = eda_df.groupby('date')[['counts']].mean().reset_index()
daily_counts['date'] = daily_counts['date'].astype(str)

daily_speed = eda_df.groupby('date')[['speed_avg']].mean().reset_index()
daily_speed['date']  = daily_speed['date'].astype(str)

daily_attributes = pd.melt(eda_df.groupby('date')[features_plot].mean().reset_index(),id_vars= ['date'])
daily_attributes['date']  = daily_attributes['date'].astype(str)

# %%
#formatter = matplotlib.dates.DateFormatter('%d')
locator = matplotlib.dates.DayLocator(interval = 2)

fig, axs = plt.subplots(1,3, figsize = (13,4))

sns.lineplot(x= 'date', y = 'counts', data = daily_counts, ax = axs[0], color = 'black')

sns.lineplot(x= 'date', y = 'speed_avg', data =daily_speed, ax = axs[1], color = 'black')

sns.lineplot(x= 'date', y = 'value', hue = 'variable', data =daily_attributes, ax = axs[2])

for ax in axs:
    #ax.xaxis.set_major_formatter(formatter)
    ax.xaxis.set_major_locator(locator)
    #ax.set_xlabel('day of October 2019')

axs[0].set_ylabel('average link flow [vehicles per hour]')
axs[1].set_ylabel('average speed [miles per hour]')

axs[2].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
axs[2].set_ylabel("average value of exogenous attribute")

#list(map(lambda x: x.set_xticklabels(x.get_xticks(), rotation=90), axs));
fig.autofmt_xdate(rotation = 90, ha = 'center')
fig.tight_layout()

# %% [markdown]
# ### By hour of day

# %%
link_keys = eda_df[(eda_df.counts>0) & (eda_df.speed_avg>0)].link_key.unique()
link_keys = link_keys[0:10]

# %%
fig, axs = plt.subplots(1,2, figsize = (10,4))

sns.lineplot(x= 'hour', y = 'counts', hue = 'link_key',
             data =eda_df[eda_df.link_key.isin(link_keys)].groupby(['hour','link_key'])[['counts']].mean().reset_index(),
             ax = axs[0])

sns.lineplot(x= 'hour', y = 'speed_avg', hue = 'link_key',
             data =eda_df[eda_df.link_key.isin(link_keys)].groupby(['hour','link_key'])[['speed_avg']].mean().reset_index(),
             ax = axs[1])
plt.show()

# %%
# Analysis for links where link counts are reported
#eda_subset_df = eda_df[~eda_df.counts.isna()].copy()
eda_subset_df = eda_df[eda_df.date == '2019-10-01'].copy()

fig, axs = plt.subplots(1,4, figsize = (20,4))

sns.lineplot(x= 'hour', y = 'counts', data =eda_subset_df.groupby(['hour'])[['counts']].mean().reset_index(),
             ax = axs[0])

sns.lineplot(x= 'hour', y = 'speed_avg',
             data =eda_subset_df.groupby(['hour'])[['speed_avg']].mean().reset_index(),
             ax = axs[1])

sns.lineplot(x= 'hour', y = 'speed_max',
             data =eda_subset_df.groupby(['hour'])[['speed_max']].max().reset_index(),
             ax = axs[2])

sns.lineplot(x= 'hour', y = 'speed_sd',
             data =eda_subset_df.groupby(['hour'])[['speed_sd']].mean().reset_index(),
             ax = axs[3])

plt.show()

# %%
# Select data from 2019 only
#eda_df = eda_df[eda_df.year == 2019]

# %%
eda_df.year
# Out:
# 0          2019
# 1          2019
# 2          2019
# 3          2019
# 4          2019
#            ...
# 1013455    2020
# 1013456    2020
# 1013457    2020
# 1013458    2020
# 1013459    2020
# Name: year, Length: 1013460, dtype: int64

# %%
# Analysis for links where link counts are reported
# Hist Av Speed(km/hour)

eda_df['rr'] =eda_df['speed_sd']/ eda_df['speed_avg']

fig, axs = plt.subplots(1,3, figsize = (13.5,4), tight_layout = True)

sns.lineplot(x= 'hour_id', y = 'counts', data =eda_df.groupby(['year','hour_id'])[['counts']].mean().reset_index(),
             ax = axs[0], hue = 'year', palette = sns.color_palette("tab10")[0:2])

sns.lineplot(x= 'hour_id', y = 'speed_avg',
             data =eda_df[~eda_df.counts.isna()].groupby(['year','hour_id'])[['speed_avg']].mean().reset_index(),
             ax = axs[1], hue = 'year', palette = sns.color_palette("tab10")[0:2])
# sns.lineplot(x= 'hour_id', y = 'rr',
#              data =eda_df[~eda_df.counts.isna()].groupby(['year','hour_id'])[['rr']].mean().reset_index(),
#              ax = axs[2], hue = 'year', palette = sns.color_palette("tab10")[0:2])
sns.lineplot(x= 'hour_id', y = 'speed_sd',
             data =eda_df[~eda_df.counts.isna()].groupby(['year','hour_id'])[['speed_sd']].mean().reset_index(),
             ax = axs[2], hue = 'year', palette = sns.color_palette("tab10")[0:2])

fig.autofmt_xdate(rotation = 90, ha = 'center')

axs[0].set_ylabel('average link flow [vehicles per hour]')
axs[1].set_ylabel('average speed [miles per hour]')
axs[2].set_ylabel('std. speed [miles per hour]')
#axs[2].set_ylabel('avg. speed / std. speed')
axs[2].set_ylim(bottom = 0)

list(map(lambda x: x.set_xlabel('hour'),axs))
list(map(lambda x: x.legend(loc = 'lower left', title = 'year'),axs))

plt.savefig('output/figures/results/fresno-hourly-eda.png')

plt.show()
